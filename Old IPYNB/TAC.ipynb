# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *deltat = recfromtxt ('Desktop/TAC.txt')ADC = recfromtxt ('Desktop/TAC2.txt')error = recfromtxt('Desktop/error.txt')print deltat, ADC
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.
# [ 0.5003  1.005   1.506   2.002   2.503   3.002   3.501   4.003   4.504  5.005   5.507   6.002   6.509   6.995   7.5     8.006   8.507   8.99  9.503 ] [ 225  431  638  840 1045 1240 1454 1660 1870 2077 2280 2484 2690 2888 3100 3310 3510 3709 3917]

# %%
figure(figsize = (10,8))plot(deltat, ADC, 'r', label = 'Best Fit Line')errorbar(deltat, ADC, error, fmt ='b.', label = 'Data Points with Errorbars')xlabel('$\Delta t$')ylabel('ADC')legend()show()

# %%
from scipy.optimize import curve_fitdef line(x, m, c):    return m*x + c

# %%
px,cov = curve_fit(line, deltat, ADC ,p0=([500, 1]))

# %%
print px
# Out:
# [ 410.67741492   17.52571098]

# %%
print sqrt(cov)
# Out:
# [[ 0.28136745         nan] [        nan  1.60458695]]
# -c:1: RuntimeWarning: invalid value encountered in sqrt
