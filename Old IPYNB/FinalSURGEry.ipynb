# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *from matplotlib import *from pylab import *
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
dats = recfromtxt ('/home/stephan/Desktop/QTisOFF.txt') noqt = recfromtxt ('/home/stephan/Desktop/POO.txt')

# %%
print shape(dats)print shape(noqt)
# Out:
# (649, 4)(649, 4)

# %%
fn = []        #File Numberphe = []       #Phe Ratensump = []     #Total N Sumpodlene = []       #Length of Etrainsnum = []       #Number      for i in range(649):    fn.append(dats[i][0])    phe.append(dats[i][1])    nsump.append(dats[i][2])    lene.append(dats[i][3])    num.append(i)    nofn = []        #File Numbernophe = []       #Phe Ratenonsump = []     #Total N Sumpodnolene = []       #Length of Etrainsnonum = []       #Number      for i in range(649):    nofn.append(noqt[i][0])    nophe.append(noqt[i][1])    nonsump.append(noqt[i][2])    nolene.append(noqt[i][3])    nonum.append(i)

# %%
figure= (figsize(10,10))#hist(phe, bins = 50, log = 'true')hist(phe, bins = 50, log = 'true', color= 'r')ylabel('Frequency')title('Phe Rate (For Etrains)')show()figure= (figsize(10,10))hist(nophe, bins=50, log = 'true', color = 'b')ylabel('Frequency')title('Phe Rate (For Etrains no QT)')show()

# %%
figure= (figsize(10,10))hist(lene, bins = 50, log = 'true', color = 'r')ylabel('Frequency')title('Length of Etrains')show()figure= (figsize(10,10))hist(nolene, bins = 50, log = 'true', color = 'b')ylabel('Frequency')title('Length of Etrains (No QT)')show()

# %%
figure= (figsize(10,10))hist(nsump, bins = 50, log = 'true', color = 'r')ylabel('Frequency')title('Total NSumpods')show()figure= (figsize(10,10))hist(nonsump, bins = 50, log = 'true', color = 'b')ylabel('Frequency')title('Total NSumpods (No QT)')show()

# %%
print 'The total length of etrains were:' , (sum(lene)/1e6)print 'With QT on:\t', (sum(nolene)/1e6)
# Out:
# The total length of etrains were: 1.012749With QT on:	1.012749

# %%
print (649./15523.)*100
# Out:
# 4.18089286865
