# %%
# %pylab inline
import pyfits,glob
import scipy.ndimage as snd
import numpy as np
from matplotlib.pyplot import *
#from array import array


def is_number(a):
    try:
        float(a)
        return True
    except ValueError:
        return False
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214.xps", "r")
Binding1 = []
Cts1 = []

for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))

searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_20.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))

            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_30.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_40.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_50.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_60.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
            
            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_70.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))

searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_80.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_90.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
            
searchfile = open("/home/stephan/Desktop/NoiseData/Noise520eV92112214_100.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))


searchfile.close()


figure = (figsize(10,10))
plot(Binding1, Cts1, 'o', alpha ='.01')
title("HP WEST: BE vs Frequency [520eV Au]")
xlabel("BE (eV)")
ylabel("Frequency (Counts)")
#ylim(0,500)
show()

# %%
figure = figsize(20,20)
hist(Cts1, label = '520 eV Average')
title('HP WEST: Counts vs Frequency')
xlabel('Counts')
ylabel('Frequency')
legend()
show()

outliers = []
for i in range(len(Cts1)):
    if (Cts1[i] == 0):
        outliers.append(Binding1[i])
print outliers

averagects = mean(Cts1)
cts1td = (std(Cts1)/10)
pdcts1 = sqrt(mean(Cts1))
d1 = ((pdcts1 - cts1td)/pdcts1)*100
print 'Standard Deviation (520 eV): ', cts1td, '\tSqrt of Average : ', pdcts1, '\tDifference: ', d1 ,'%'
print averagects
# Out:
# [515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.436, 515.4, 515.4
# ...

# %%
#General Scan
Binding1 = []
Cts1 = []

searchfile = open("/home/stephan/Desktop/NoiseData/Quick112514.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))


searchfile.close()


figure = (figsize(10,10))
plot(Binding1, Cts1)
title("HP WEST: BE Sweep")
xlabel("BE (eV)")
ylabel("Frequency (Counts)")
#ylim(0,500)
show()
