# %%
# %pylab inline
import pyfits,glob
import scipy.ndimage as snd
import numpy as np
from matplotlib.pyplot import *

def is_number(a):
    try:
        float(a)
        return True
    except ValueError:
        return False
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#searchfile = open("/home/stephan/Desktop/Batch2_10Cu854_111414.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))
#searchfile.close()            
searchfile = open("/home/stephan/Desktop/Batch2_20Cu854_111414.xps", "r")
Binding1 = []
Cts1 = []

for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
searchfile.close()
searchfile = open("/home/stephan/Desktop/Batch2_30Cu854_111414.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
searchfile.close()
            
searchfile = open("/home/stephan/Desktop/Batch2_40Cu854_111414.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding1.append(float(data[0]))
            Cts1.append(float(data[1]))
searchfile.close()            
            
#searchfile = open("/home/stephan/Desktop/Noise/Attempt1_50Cu111014.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))

            
            
#searchfile = open("/home/stephan/Desktop/Noise/Attempt1_60Cu111014.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))

            
#searchfile = open("/home/stephan/Desktop/Noise/Attempt1_70Cu111014.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))

            
            
#searchfile = open("/home/stephan/Desktop/Noise/Attempt1_80Cu111014.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))

            
            
#searchfile = open("/home/stephan/Desktop/Noise/Attempt1_90Cu111014.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))

            
            
#searchfile = open("/home/stephan/Desktop/Noise/Attempt1_100Cu111014.xps", "r")
#for line in searchfile:
#    data = line.split()
#    if (data):
#        if(is_number(data[0])):
#            Binding.append(float(data[0]))
#            Cts.append(float(data[1]))

            

figure = (figsize(10,10))
plot(Binding1, Cts1, 'o', alpha ='.1')
title("HP WEST: BE vs Frequency")
xlabel("BE (eV)")
ylabel("Frequency (Counts)")
#ylim(0,500)
show()
#    print is_number(data[0])
#    if (is_number(data[0]) == 4'True'):
 #       print data
#    for i in range(len(data)):
        #print data[i]
 #           print data

# %%
# Out:
# (array([  60,   30,   41,   62,  158,  801,  956, 2467, 2346,  759]),
#  array([    0.,   230.,   460.,   690.,   920.,  1150.,  1380.,  1610.,
#         1840.,  2070.,  2300.]),
#  <a list of 10 Patch objects>)

# %%
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_10Cu111014.xps", "r")
Binding = []
Cts = []
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))
            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_20Cu111014.xps.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

searchfile = open("/home/stephan/Desktop/Noise/Attempt1_30Cu111014.xps.xps.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_40Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))
            
            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_50Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            
            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_60Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_70Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            
            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_80Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            
            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_90Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            
            
searchfile = open("/home/stephan/Desktop/Noise/Attempt1_100Cu111014.xps", "r")
for line in searchfile:
    data = line.split()
    if (data):
        if(is_number(data[0])):
            Binding.append(float(data[0]))
            Cts.append(float(data[1]))

            

figure = (figsize(10,10))
plot(Binding, Cts, 'o', alpha ='.01')
title("HP WEST: BE vs Frequency")
xlabel("BE (eV)")
ylabel("Frequency (Counts)")
show()
#    print is_number(data[0])
#    if (is_number(data[0]) == 4'True'):
 #       print data
#    for i in range(len(data)):
        #print data[i]
 #           print data
searchfile.close()
figure = figsize(20,20)
hist(Cts, label = '552 eV Average')
hist(Cts1, label = '854 eV Average (Work in progress)')
title('HP WEST: Counts vs Frequency')
xlabel('Counts')
ylabel('Frequency')
legend()
show()

ctstd = (std(Cts)/10)
cts1td = (std(Cts1)/10)
pdcts = sqrt(mean(Cts))
pdcts1 = sqrt(mean(Cts1))
d = ((pdcts - ctstd)/pdcts)*100
d1 = ((pdcts1 - cts1td)/pdcts1)*100
print 'Standard Deviation (552 eV): ', ctstd, '\tSqrt of Average : ', pdcts, '\tDifference: ', d, '%'
print 'Standard Deviation (854 eV): ', cts1td, '\tSqrt of Average : ', pdcts1, '\tDifference: ', d1 ,'%'
# Out:
# Standard Deviation (552 eV):  33.6415331171 	Sqrt of Average :  41.5102345249 	Difference:  18.9560514362 %
# Standard Deviation (854 eV):  33.8920394883 	Sqrt of Average :  41.4464058429 	Difference:  18.2268310145 %

# %%
#print Binding
#print Cts

# %%
sb = []
sc = [] 
j = 0
certain = 555.337
mcertain = certain - .1
pcertain = certain + .1
for i in range(len(Binding)):
    j = i 
#    if (Binding[i] > mcertain and Binding[i] < pcertain):
    if (Binding[i] == certain):
        sc.append(Cts[i])
#sb[1]
#sb.sort
#print sb

#print j
#print sb
print sc
#plot(sb, sc, 'o')
hist(sc, bins = 10)
# Out:
# [1903.0, 1886.0, 1842.0, 1867.0, 1890.0, 1849.0, 1826.0, 1907.0, 1810.0, 1885.0, 1848.0, 1847.0, 1892.0, 1873.0, 1810.0, 1864.0, 1829.0, 1912.0, 1823.0, 1932.0, 1827.0, 1831.0, 1790.0, 1833.0, 1860.0, 1881.0, 1919.0, 1894.0, 1830.0, 1941.0, 1857.0, 1889.0, 1887.0, 1971.0, 1869.0, 1871.0, 1824.0, 1832.0, 1906.0, 1865.0, 1847.0, 1861.0, 1795.0, 1876.0, 1881.0, 1798.0, 1923.0, 1919.0, 1870.0, 1938.0, 1823.0, 1929.0, 1857.0, 1881.0, 1911.0, 1988.0, 1869.0, 1959.0, 1905.0, 1938.0, 1910.0, 1879.0, 1849.0, 1883.0, 1849.0, 1892.0, 1860.0, 1972.0, 1907.0, 1889.0, 1924.0, 1862.0, 1925.0, 1938.0, 1979.0, 1874.0, 1901.0, 1907.0, 1928.0, 1912.0, 1893.0, 1903.0, 1924.0, 1898.0, 1878.0, 1791.0, 1878.0, 1841.0, 1951.0, 1860.0, 1961.0, 1858.0, 1860.0, 1942.0, 1840.0, 1846.0, 1891.0, 1922.0, 1869.0, 1852.0]
# (array([ 4,  8, 14, 16, 15, 17, 12,  7,  3,  4]),
#  array([ 1790. ,  1809.8,  1829.6,  1849.4,  1869.2,  1889. ,  1908.8,
#         1928.6,  1948.4,  1968.2,  1988. ]),
# ...

# %%
#a = [1,3,2,1.12,12,3.12,312.31,32,123.2,21,1.12,3]
#print a
#a.sort()
#print a

# %%
#print Binding

# %%
#Binding = [1,2,3,4,15,12,3,5,1,2,3,5,5,6,12,2,3,5,1,2]

# %%
Binding.sort()
#print "Binding = ", Binding

# %%
d = {}
rr = {}
pos = []
Reduced = [Binding[0]]
    
for i in range(len(Binding)):
    if (Binding[i] > Binding[i-1]):
        Reduced.append(Binding[i])
        
        
print "Reduced =", Reduced

for x in range(len(Reduced)):
    d[format(x)] = []
    
for i in range(len(Reduced)):
    for j in range(len(Binding)):
        if (Binding[j] == Reduced[i]):
            pos.append(j)
            k = str(format(i)) 
            #print k, pos
    #k = str('BEV' + str(i))
    #k = **k
    #print k, 'k'
    #h = k
    #print type(k) is str
    #print d
    #d = dict('k':pos)
    #d.update(['1', pos])
    #print pos
    if (i == 0):
        rr = {i: pos}
        print 'once'
    rr[i] = pos
    pos = []

#print 'These markers hold all similar values.\n', rr

#Values are called with
#print rr.get(#)
# Out:
# Reduced = [547.4, 547.436, 547.472, 547.508, 547.544, 547.58, 547.616, 547.653, 547.689, 547.725, 547.761, 547.797, 547.833, 547.869, 547.905, 547.941, 547.977, 548.013, 548.049, 548.085, 548.122, 548.158, 548.194, 548.23, 548.266, 548.302, 548.338, 548.374, 548.41, 548.446, 548.482, 548.518, 548.555, 548.591, 548.627, 548.663, 548.699, 548.735, 548.771, 548.807, 548.843, 548.879, 548.915, 548.951, 548.987, 549.024, 549.06, 549.096, 549.132, 549.168, 549.204, 549.24, 549.276, 549.312, 549.348, 549.384, 549.42, 549.456, 549.493, 549.529, 549.565, 549.601, 549.637, 549.673, 549.709, 549.745, 549.781, 549.817, 549.853, 549.889, 549.925, 549.962, 549.998, 550.034, 550.07, 550.106, 550.142, 550.178, 550.214, 550.25, 550.286, 550.322, 550.358, 550.395, 550.431, 550.467, 550.503, 550.539, 550.575, 550.611, 550.647, 550.683, 550.719, 550.755, 550.791, 550.827, 550.864, 550.9, 550.936, 550.972, 551.008, 551.044, 551.08, 551.116, 551.152, 551.188, 551.224, 551.26, 551.296, 551.333, 551.369, 55
# ...

# %%
sc = [] 
for j in range(len(Reduced)):
    sc = []
    for i in range(len(Binding)):
        if (Binding[i] == Reduced[j]):
            sc.append(Cts[i])
    print 'This is the :', j, 'Number \t\t With a reduced value of: ', Reduced[j], 'eV'
    figure = (figsize(15,10))
    hist(sc, bins = 10)#, histtype = 'step')
    xlabel('Counts')
    ylabel('Frequency')
    show()
print sc
#plot(sb, sc, 'o')
# Out:
# This is the : 0 Number 		 With a reduced value of:  547.4 eV
# This is the : 1 Number 		 With a reduced value of:  547.436 eV
# This is the : 2 Number 		 With a reduced value of:  547.472 eV
# This is the : 3 Number 		 With a reduced value of:  547.508 eV
# This is the : 4 Number 		 With a reduced value of:  547.544 eV
# This is the : 5 Number 		 With a reduced value of:  547.58 eV
# This is the : 6 Number 		 With a reduced value of:  547.616 eV
# This is the : 7 Number 		 With a reduced value of:  547.653 eV
# This is the : 8 Number 		 With a reduced value of:  547.689 eV
# This is the : 9 Number 		 With a reduced value of:  547.725 eV
# This is the : 10 Number 		 With a reduced value of:  547.761 eV
# This is the : 11 Number 		 With a reduced value of:  547.797 eV
# This is the : 12 Number 		 With a reduced value of:  547.833 eV
# This is the : 13 Number 		 With a reduced value of:  547.869 eV
# This is the : 14 Number 		 With a reduced value of:  547.905 eV
# ...

# %%
#pos = []
#for j in range(len(Reduced)):
#for i in range(len(Binding)):
#    if (Binding[i] == Reduced[0]):
#        pos.append(i)
#print pos

# %%
history = rr.get(1)
print history
# Out:
# [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199]

# %%
print Reduced
# Out:
# [547.4, 547.436, 547.472, 547.508, 547.544, 547.58, 547.616, 547.653, 547.689, 547.725, 547.761, 547.797, 547.833, 547.869, 547.905, 547.941, 547.977, 548.013, 548.049, 548.085, 548.122, 548.158, 548.194, 548.23, 548.266, 548.302, 548.338, 548.374, 548.41, 548.446, 548.482, 548.518, 548.555, 548.591, 548.627, 548.663, 548.699, 548.735, 548.771, 548.807, 548.843, 548.879, 548.915, 548.951, 548.987, 549.024, 549.06, 549.096, 549.132, 549.168, 549.204, 549.24, 549.276, 549.312, 549.348, 549.384, 549.42, 549.456, 549.493, 549.529, 549.565, 549.601, 549.637, 549.673, 549.709, 549.745, 549.781, 549.817, 549.853, 549.889, 549.925, 549.962, 549.998, 550.034, 550.07, 550.106, 550.142, 550.178, 550.214, 550.25, 550.286, 550.322, 550.358, 550.395, 550.431, 550.467, 550.503, 550.539, 550.575, 550.611, 550.647, 550.683, 550.719, 550.755, 550.791, 550.827, 550.864, 550.9, 550.936, 550.972, 551.008, 551.044, 551.08, 551.116, 551.152, 551.188, 551.224, 551.26, 551.296, 551.333, 551.369, 551.405, 551
# ...

# %%
allstddev = []
allsqrtavg = []
for i in range(len(Reduced)):
    counters = []
    for j in range(len(Binding)):
        if (Reduced[i] == Binding[j]):
            counters.append(Binding[j])
    lcts = len(counters)
    acts = mean(counters)
    for k in range (len(counters)):
        pcts = (acts - counters[k])**2
        scts = sqrt((1./lcts)*pcts)
    sqcts = (acts**.5)
    allstddev.append(scts)
    allsqrtavg.append(sqcts)
    print 'Length : ', lcts, ',\tAverage : ', acts, ',\tStandard Deviation : ', scts, '\t', (std(counters))/10, ',\tThe square root of the average of is : ', sqcts 
hist(allstddev)
show()
hist(allsqrtavg)
show()
# Out:
# Length :  100 ,	Average :  547.4 ,	Standard Deviation :  1.02318153949e-13 	1.02318153949e-13 ,	The square root of the average of is :  23.3965809468
# Length :  100 ,	Average :  547.436 ,	Standard Deviation :  1.02318153949e-13 	1.02318153949e-13 ,	The square root of the average of is :  23.3973502773
# Length :  100 ,	Average :  547.472 ,	Standard Deviation :  1.13686837722e-13 	1.13686837722e-13 ,	The square root of the average of is :  23.3981195826
# Length :  100 ,	Average :  547.508 ,	Standard Deviation :  1.13686837722e-13 	1.13686837722e-13 ,	The square root of the average of is :  23.3988888625
# Length :  100 ,	Average :  547.544 ,	Standard Deviation :  1.25055521494e-13 	1.25055521494e-13 ,	The square root of the average of is :  23.3996581172
# Length :  100 ,	Average :  547.58 ,	Standard Deviation :  1.25055521494e-13 	1.25055521494e-13 ,	The square root of the average of is :  23.4004273465
# ...
