# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *def Kelvin(x):    count = 273.15 + x    print count#Kelvin(80)#Kelvin(85)#Kelvin(90)#Kelvin(95)#Kelvin(100)K = [353.15, 358.15, 363.15, 368.15, 373.15]VP = [473.4, 578.1, 700.9, 845.1, 1013.25]figure(figsize=(10,10))plot(VP, K)xlabel('Vapor Pressure')ylabel('Kelvin')
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.
