# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *from matplotlib import *from pylab import *
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
feap = recfromtxt("/home/stephan/Documents/phestuff.txt")sump = recfromtxt("/home/stephan/Documents/sumpods.txt")asym = recfromtxt("/home/stephan/Desktop/combo.txt")cut = []for i in range(len(feap)):    if (feap[i] > 10**9):        cut.append(feap[i])figure= (figsize(10,10))hist(cut, log = 'true')#, bins = 100)#, histtype = 'stepfilled', alpha = '.5')#xlabel('')ylabel('Counts')title('Full EVT Area Phe')show()figure= (figsize(10,10))hist(sump, log = 'true')#, histtype = 'stepfilled', alpha = '.5')#xlabel('')ylabel('Counts')title('Total N Sumpods')show()figure= (figsize(10,10))hist(asym, log = 'true')#, histtype = 'stepfilled', alpha = '.5')xlabel('(hstart-hend)/(hstart+hend)')ylabel('Counts')title('Asymmetric Graph')show()
