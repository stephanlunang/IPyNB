# %%
# %pylab inlinefrom math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialavg1 = 6.12avg2 = 6.4Freq = zeros(1)data=recfromtxt ('Desktop/histdata.txt')[:,1]#poisson2 = recfromtxt('Desktop/poisson2.txt')#print poissonn_bin, bin_edges = histogram(data, arange(13))y,binEdges=histogram(data,bins= arange(13))t_bin = bin_edges[:-1]bincenters = 0.5*(binEdges[1:]+binEdges[:-1])#print data, '\n', y, '\n' , binEdges, '\n' , bin_edges, '\n', t_binFreq =(50*(avg2 ** t_bin) * exp(-avg2))/(factorial(t_bin))menStd     = sqrt(y)width=.5figure(figsize=(10,10))bar(bincenters,y,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')bar(bincenters+.5, Freq, width = width, color ='g', label = 'Poisson Distribution')title('Run 2 Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
# %pylab inlinefrom math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialfigure(figsize=(10,10))avg1 = 6.12avg2 = 6.4Freq = zeros(1)data=recfromtxt ('Desktop/histdata.txt')[:,0]#poisson = recfromtxt('Desktop/poisson.txt')#print poissonn_bin, bin_edges = histogram(data, arange(13))y,binEdges=histogram(data,bins= arange(13))t_bin = bin_edges[:-1]bincenters = 0.5*(binEdges[1:]+binEdges[:-1])#print data, '\n', y, '\n' , binEdges, '\n' , bin_edges, '\n', t_binFreq =(50*(avg1 ** t_bin) * exp(-avg1))/(factorial(t_bin))menStd     = sqrt(y)width=.5bar(bincenters,y,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')bar(bincenters+.5, Freq, width = width, color ='g', label = 'Poisson Distribution')title('Run 1 Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
# %pylab inlinefrom math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialfigure(figsize=(10,10))avgdata = 463.54Freq = zeros(1)data=recfromtxt ('Desktop/combined.txt')n_bin, bin_edges = histogram(data, arange(383,588,17))t_bin = bin_edges[:-1]#print data, '\n', n_bin, '\n' , '\n' , bin_edges, '\n This is t_bin', t_bin#Freq =(50*(avgdata ** t_bin) * exp(-avgdata))/(factorial(t_bin))counts_bar = mean(data)#print counts_barFreq = 25 * sum(n_bin) / (sqrt(2 * pi * counts_bar)) * exp((-(t_bin + 12.5 - counts_bar) ** 2) / (2 * counts_bar))#print FreqmenStd     = sqrt(n_bin)errorbar (t_bin, n_bin, menStd, fmt = 'r.', label ='Data')width=5plot(t_bin,n_bin, 'bo', label = 'Data with Error Bars')plot(t_bin, Freq, 'g', label = 'Gaussian Distribution')#bar(t_bin,n_bin,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')#bar(t_bin+5, Freq, width = width, color ='purple', label = 'Gaussian Distribution')title('Combined Cesium 137 Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
# %pylab inlinefigure(figsize=(10,10))from math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialavg1 = 6.12avg2 = 6.4Freq = zeros(1)data=recfromtxt ('Desktop/bkgrdcomb.txt')n_bin, bin_edges = histogram(data, arange(13))y,binEdges=histogram(data,bins= arange(13))t_bin = bin_edges[:-1]bincenters = 0.5*(binEdges[1:]+binEdges[:-1])#print data, '\n', y, '\n' , binEdges, '\n' , bin_edges, '\n', t_binFreq =(100*(avg1 ** t_bin) * exp(-avg1))/(factorial(t_bin))#print FreqmenStd     = sqrt(y)width=.5bar(bincenters,y,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')bar(bincenters+.5, Freq, width = width, color ='g', label = 'Poisson Distribution')title('Combined Background Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
# %pylab inlinefrom math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialfigure(figsize=(10,10))avgdata = 463.38Freq = zeros(1)data=recfromtxt ('Desktop/data.txt')[:,0]n_bin, bin_edges = histogram(data, arange(383,588,17))t_bin = bin_edges[:-1]#print data, '\n', n_bin, '\n' , '\n' , bin_edges, '\n This is t_bin', t_bin#Freq =(50*(avgdata ** t_bin) * exp(-avgdata))/(factorial(t_bin))counts_bar = mean(data)#print counts_barFreq = 25 * sum(n_bin) / (sqrt(2 * pi * counts_bar)) * exp((-(t_bin + 12.5 - counts_bar) ** 2) / (2 * counts_bar))#print FreqmenStd     = sqrt(n_bin)errorbar (t_bin, n_bin, menStd, fmt = 'r.', label ='Data')width=5plot(t_bin,n_bin, 'bo', label = 'Data Points with Error Bars')plot(t_bin, Freq, 'g', label = 'Gaussian Distribution')#bar(t_bin,n_bin,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')#bar(t_bin+5, Freq, width = width, color ='purple', label = 'Gaussian Distribution')title('Run 1 Cesium 137 Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
# %pylab inlinefrom math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialfigure(figsize=(10,10))avgdata = 462.8Freq = zeros(1)data=recfromtxt ('Desktop/data.txt')[:,1]n_bin, bin_edges = histogram(data, arange(383,588,17))t_bin = bin_edges[:-1]#print data, '\n', n_bin, '\n' , '\n' , bin_edges, '\n This is t_bin', t_bin#Freq =(50*(avgdata ** t_bin) * exp(-avgdata))/(factorial(t_bin))counts_bar = mean(data)#print counts_barFreq = 25 * sum(n_bin) / (sqrt(2 * pi * counts_bar)) * exp((-(t_bin + 12.5 - counts_bar) ** 2) / (2 * counts_bar))errorbar (t_bin, n_bin, menStd, fmt = 'r.', label ='Data')#print FreqmenStd     = sqrt(n_bin)width=5plot(t_bin,n_bin, 'bo', label = 'Data with Error Bars')plot(t_bin, Freq, 'g', label = 'Gaussian Distribution')#bar(t_bin,n_bin,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')#bar(t_bin+5, Freq, width = width, color ='purple', label = 'Gaussian Distribution')title('Run 2 Cesium 137 Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
# %pylab inlinefrom math import *from numpy import *from matplotlib.pyplot import *from scipy.misc import factorialfrom scipy.optimize import leastsqfigure(figsize=(10,10))avgdata = 464.44Freq = zeros(1)data=recfromtxt ('Desktop/data.txt')[:,2]n_bin, bin_edges = histogram(data, arange(383,588,17))t_bin = bin_edges[:-1]#print data, '\n', n_bin, '\n' , '\n' , bin_edges, '\n This is t_bin', t_bin#Freq =(50*(avgdata ** t_bin) * exp(-avgdata))/(factorial(t_bin))counts_bar = mean(data)#print counts_barFreq = 25 * sum(n_bin) / (sqrt(2 * pi * counts_bar)) * exp((-(t_bin + 12.5 - counts_bar) ** 2) / (2 * counts_bar))#print FreqmenStd     = sqrt(n_bin)width=5plot(t_bin,n_bin, 'bo', label = 'Data with Error Bars')errorbar (t_bin, n_bin, menStd, fmt = 'r.', label ='Data')##########################################################fitfxn = lambda p, x : p[2]+p[0]*exp(-p[1]*x)##############################################################errfxn = lambda p, x, y: fitfxn(p,x) -y#parameters, foo = leastsq(errfxn, (300, 3, 5), args=(t_bin, n_bin))    #plot(t_bin, fitfxn(parameters, t_bin), 'r', linewidth = 4, label='Fit function')plot(t_bin, Freq, 'g', label = 'Gaussian Distribution')#bar(t_bin,n_bin,width=width, color='r', yerr=menStd, label = 'Data with Error Bars')#bar(t_bin+5, Freq, width = width, color ='purple', label = 'Gaussian Distribution')title('Run 3 Cesium 137 Data Set')xlabel('Counts per time interval')ylabel('Frequency')legend()show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.
