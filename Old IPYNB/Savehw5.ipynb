# %%
pi = 3.14159265359 G = 6.67384*10**-11M1 = (1.3*(10**10))M2 = (6.5*(10**10))M3 = (10**9)M4 = 2*10**12Mtk = (1.9891*(10**30))kpm = (3.08567758*(10**19))a1 = .4a2 = 4a3 = .5Maxa = 30figure(figsize=(10,10))r = [0.]j = 0.Massb = [0]Massh = [0]Massd = [0]DarkMatter = [0]MassSum = [0]velbulge = [0]velhalo = [0]veldisk = [0]veldark = [0]inc = .01while j < Maxa:    Massb.append((M1*(j)**3)/(3*(a1**2+j**2)**(1.5)))    Massh.append((4*pi*M3*((-8.65801*a3**2-18.1818*a3*j-10*j**2)/(a3+j)**2.1+8.65801*a3**(-0.1))))  #Gathered via Wolframalpha    Massd.append(( - M2 * exp(-j / a2) * (a2 + j) / a2) + M2)    DarkMatter.append((M4/30)*j)        j = j + inc    r.append(j)        velbulge.append((((G*Massb[-1]*Mtk)/(j*(kpm)))**(.5))/1000.)    velhalo.append((((G*Massh[-1]*Mtk)/(j*(kpm)))**(.5))/1000.)    veldisk.append((((G*Massd[-1]*Mtk)/(j*(kpm)))**(.5))/1000.)        MassSum.append(Massb[-1]+Massh[-1]+Massd[-1]+DarkMatter[-1])    veldark.append((((G*MassSum[-1]*Mtk)/(r[-1]*(kpm)))**(.5))/1000.)            #print Mass1, r#print velbulgeplot(r, velbulge)title('Bulge Graph')xlabel('Distance (Kpc)')ylabel('Velocity (km/s)')show()figure(figsize=(10,10))plot(r, velhalo)title('Halo Graph')xlabel('Distance (Kpc)')ylabel('Velocity (km/s)')show()figure(figsize=(10,10))plot(r, veldisk)title('Disk Graph')xlabel('Distance (Kpc)')ylabel('Velocity (km/s)')show()figure(figsize=(10,10))plot(r, veldark)title('Dark Graph')xlabel('Distance (Kpc)')ylabel('Velocity (km/s)')show()#rhor2 = M*(10**9)*smass*(a+r)**-3.1#projrho = M/(2*pi*(a**2)*(e**(r/a)))#dmdr2 = 2*pi*r*projrho
