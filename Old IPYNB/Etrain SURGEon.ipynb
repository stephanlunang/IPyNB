# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *from matplotlib import *from pylab import *
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
combo = recfromtxt ('/home/stephan/textanalysis/p1.txt')

# %%
fn = []pi = []st = []ed = []num = []for i in range(len(combo)):    fn.append(combo[i][0])    pi.append(combo[i][1])    st.append(combo[i][2])    ed.append(combo[i][3])    num.append(i)

# %%
#etrain pulleretst = []eted = []for i in range(len(combo)):    if (combo[i][1] == 8):        etst.append(combo[i][2])        eted.append(combo[i][3])

# %%
#fn = [10, 1000, 100, 9, 3]stdfn = []place = 0for i in range(len(fn)):    if (fn[i] < 10):        place = '000' + str(fn[i])    if (fn[i] > 9 & fn[i] < 100):        place = '00' + str(fn[i])    if (fn[i] > 99 & fn[i] < 1000):        place = '0' + str(fn[i])    if (fn[i] > 999):        place = str(fn[i])    stdfn.append(place)    #print stdfn

# %%
nonfn = []nonpi = []fnet = []for i in range(len(pi)):#    print i    if (pi[i] < 10 and fn[i] > 0):        nonfn.append(fn[i])        nonpi.append(pi[i])    if (pi[i] > 8 or pi[i] < 0):        print fn[i], '\t\t', pi[i]    if (pi[i] == 8):        fnet.append(fn[i])print '\n', fnet
# Out:
# -1776877568 		-6207412310 		989871682-1892570818 		1064265452
# []

# %%
for i in range(len(pi)):    if (pi[i] == 0):        print fn[i], '\t', pi[i]
# Out:
# -1776877568 	0-1776877568 	0-1776877568 	00 	00 	0-1776877568 	0-1776877568 	0-1776877568 	0

# %%
print len(fn), len(pi)
# Out:
# 37841 37841

# %%
pi0 = []fn0 = []st0 = []ed0 = []pi1 = []fn1 = []st1 = []ed1 = []pi2 = []fn2 = []st2 = []ed2 = []pi3 = []fn3 = []st3 = []ed3 = []pi4 = []fn4 = []st4 = []ed4 = []pi5 = []fn5 = []st5 = []ed5 = []pi6 = []fn6 = []st6 = []ed6 = []pi7 = []fn7 = []st7 = []ed7 = []pi8 = []fn8 = []st8 = []ed8 = []for i in range(len(nonfn)):    if (nonpi[i] == 0):        pi0.append(nonpi[i])        fn0.append(nonfn[i])        st0.append(st[i])        ed0.append(ed[i])    if (nonpi[i] == 1):        pi1.append(nonpi[i])        fn1.append(nonfn[i])        st1.append(st[i])        ed1.append(ed[i])    if (nonpi[i] == 2):        pi2.append(nonpi[i])        fn2.append(nonfn[i])        st2.append(st[i])        ed2.append(ed[i])    if (nonpi[i] == 3):        pi3.append(nonpi[i])        fn3.append(nonfn[i])        st3.append(st[i])        ed3.append(ed[i])    if (nonpi[i] == 4):        pi4.append(nonpi[i])        fn4.append(nonfn[i])        st4.append(st[i])        ed4.append(ed[i])    if (nonpi[i] == 5):        pi5.append(nonpi[i])        fn5.append(nonfn[i])        st5.append(st[i])        ed5.append(ed[i])    if (nonpi[i] == 6):        pi6.append(nonpi[i])        fn6.append(nonfn[i])        st6.append(st[i])        ed6.append(ed[i])    if (nonpi[i] == 7):        pi7.append(nonpi[i])        fn7.append(nonfn[i])        st7.append(st[i])        ed7.append(ed[i])    if (nonpi[i] == 8):        pi8.append(nonpi[i])        fn8.append(nonfn[i])         st8.append(st[i])        ed8.append(ed[i])

# %%
figure(figsize=(10,10))plot(fn1, pi1, '.', alpha = '.1', label = 'S1')plot(fn2, pi2, '+', alpha = '.5', label = 'S2')plot(fn3, pi3, '+', label = 'Single Photon')plot(fn4, pi4, '+', alpha = '.01', label = 'Single Electron')plot(fn5, pi5, '+', alpha = '.01', label = 'Unknown')plot(fn6, pi6, '+', alpha = '.5', label = 'Baseline Function')plot(fn7, pi7, '+', alpha = '.5', label = 'Cherenkov')plot(fn8, pi8, '+', alpha = '.5', label = 'Electron Train')xlabel('File Number')ylabel('Pulse Classification')ylim(0, 10)legend()show()

# %%
for i in range(len(nonpi)):    if (nonpi[i] == 0):        print 'Empty'

# %%
figure(figsize=(10,10))plot(fn1, st1, '.', alpha = '.5', label = 'PI 1')plot(fn2, st2, '.', alpha = '.5', label = 'PI 2')plot(fn3, st3, '.', alpha = '.5', label = 'PI 3')plot(fn4, st4, '.', alpha = '.5', label = 'PI 4')plot(fn5, st5, '.', alpha = '.5', label = 'PI 5')plot(fn6, st6, '.', alpha = '.5', label = 'PI 6')plot(fn7, st7, '.', alpha = '.5', label = 'PI 7')plot(fn8, st8, '.', alpha = '.5', label = 'PI 8')xlabel('File Number')ylabel('From Start Time')ylim(0, 10)legend()show()

# %%
figure(figsize=(10,10))plot(fn1, ed1, '.', alpha = '.5', label = 'PI 1')plot(fn2, ed2, '.', alpha = '.5', label = 'PI 2')plot(fn3, ed3, '.', alpha = '.5', label = 'PI 3')plot(fn4, ed4, '.', alpha = '.5', label = 'PI 4')plot(fn5, ed5, '.', alpha = '.5', label = 'PI 5')plot(fn6, ed6, '.', alpha = '.5', label = 'PI 6')plot(fn7, ed7, '.', alpha = '.5', label = 'PI 7')plot(fn8, ed8, '.', alpha = '.5', label = 'PI 8')xlabel('File Number')ylabel('Pulse Classification')ylim(0, 10)legend()show()
