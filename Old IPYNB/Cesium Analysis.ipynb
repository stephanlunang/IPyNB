# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *t_dat = recfromtxt ('Desktop/Allruns.txt')[:,:]print t_dat[0:100]
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.
# [[463 465 445] [479 486 449] [474 470 471] [471 445 497] [495 469 464] [466 443 462] [458 447 433] [441 477 494] [435 502 491] [448 488 478] [459 445 460] [474 471 483] [465 418 487] [454 456 485] [461 479 433] [448 479 475] [437 453 486] [471 455 464] [472 463 481] [461 468 487] [471 480 505] [447 463 467] [485 481 458] [467 448 432] [493 419 473] [466 413 456] [452 486 452] [459 444 465] [458 471 482] [439 460 458] [445 509 468] [461 458 473] [447 439 422] [440 519 457] [450 462 435] [487 413 472] [475 456 455] [482 468 458] [461 481 476] [480 438 435] [446 470 474] [457 477 468] [482 470 427] [471 509 431] [495 439 476] [446 427 471] [455 464 458] [485 469 460] [468 460 471] [467 468 462]]

# %%
figure(figsize=(10,10))hist(t_dat)xlabel('Count Number')ylabel('Frequency')title('Histogram of Three Data Sets')

# %%
comb_dat = recfromtxt ('Desktop/combined.txt')y,binEdges=histogram(comb_dat,bins= 520)bincenters = 0.5*(binEdges[1:]+binEdges[:-1])menStd     = sqrt(y)width=1figure(figsize=(30,30))bar(bincenters,y,width=width, color='r', yerr=menStd)xlabel('Count Number')ylabel('Frequency')title('Histogram of All Cesium 137 Data Sets Combined')show()hist(comb_dat, rwidth = .5)
# Out:
# (array([ 5,  6, 12, 21, 34, 36, 24,  7,  2,  3]), array([ 413. ,  423.6,  434.2,  444.8,  455.4,  466. ,  476.6,  487.2,        497.8,  508.4,  519. ]), <a list of 10 Patch objects>)
