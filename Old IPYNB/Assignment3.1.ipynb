# %%
#dp/dz = -ro*g = -PM/RT *g%pylab inlineg = -9.8ro1 = 1ro2 = .5#P(z) = -g*ro*zGradP1 = -g*ro1GradP2 = -g*ro2print 'Answer for B\nThis is the pressure gradient at 0m :', GradP1, 'Pa/m \nThis is the pressure gradient at 5500m :', GradP2, 'Pa/m \nThe pressure gradient is largest at lower altitude.\n't_day = 299.8t_night = 283.2R = 8.1344621 P = 100000M = 287ro3 = (P/(M*t_day))ro4 = (P/(M*t_night))newro = ro4-ro3GradP3 = -g*ro3GradP4 = -g*ro4DiffG = GradP4 - GradP3print  '\nThe Change in the Pressure Gradient is:', newro, 'Pa/m \nGradient During the Day is:', GradP3, 'Pa/m \nGradient During the Night is:', GradP4, 'Pa/m\nThis is the difference in the Pressure Gradient between night and day:', DiffG, 'Pa/m'
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.
# Answer for BThis is the pressure gradient at 0m : 9.8 Pa/m This is the pressure gradient at 5500m : 4.9 Pa/m The pressure gradient is largest at lower altitude.The Change in the Pressure Gradient is: 0.0681241840775 Pa/m Gradient During the Day is: 11.3897069591 Pa/m Gradient During the Night is: 12.0573239631 Pa/mThis is the difference in the Pressure Gradient between night and day: 0.667617003959 Pa/m

# %%
from matplotlib.pyplot import *Davish = 0Tahoeh = 200+DavishTempgrad = .0065 #K/kmdef Pa_mbar (x):    mbar = x*.01    Vpressure = [473.4, 578.1, 700.9, 845.1, 1013.25]T = [353.13,358.15,363.15,368.15,373.15]Tz = t_day - (Tempgrad*Tahoeh)  #T = T_0 + k*zP2 = ((Tz*P)/t_day)Pa_mbar(P2)#print t_day, '\n', P2print 'This is the temperature of Tahoe:' , Tz, 'degrees K.'print 'This is the change in Pressure between Davis and Tahoe', P-P2, 'Pa'print 'Water boils at approximately 373 degrees in Tahoe.'figure(figsize=(10,10))plot(Vpressure, T)title ('Vapor Pressure vs Temperature')xlabel('Vapor Pressure')ylabel('Kelvin')show()
# Out:
# This is the temperature of Tahoe: 298.5 degrees K.This is the change in Pressure between Davis and Tahoe 433.622414943 PaWater boils at approximately 373 degrees in Tahoe.
