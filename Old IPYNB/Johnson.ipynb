# %%
# %pylab inlinefrom numpy import *from matplotlib.pyplot import *from scipy.optimize import leastsq
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
#Resistor = recfromtxt ('Desktop/reducedJohnson.txt')[0,0]#Bin_sum = recfromtxt ('Desktop/reducedJohnson.txt')[:,1,1]Values = loadtxt('Desktop/reducedJohnson.txt')print Values[:,0]Resistor = []Bin_sum = []Dev = []for i in range(len(Values[:,0])):    Resistor.append(Values[i,0])    Bin_sum.append(Values[i,1])    Dev.append(Values[i,2])figure(figsize = (10,10))               errorbar(Resistor, Bin_sum, Dev, fmt = 'b.', label = 'Data with Error Bars')plot(Resistor, Bin_sum, 'r', label = 'Averages')legend()show()#print Values[:,0]
# Out:
# [  3.00000000e+02   1.00000000e+03   3.00000000e+03   6.00000000e+03   1.00000000e+04   3.00000000e+04   6.00000000e+04   1.00000000e+05   5.00000000e+05   1.00000000e+06]

# %%
plot(Resistor, Bin_sum, 'o')#print ResistorR_real = []for i in range(len(Resistor)):    R_real.append(1000*Resistor[i])R = []Sum_bin = []avg = []Rkt = 0R.append(Resistor[0])print R_real#def stddev(x, a):    for i in range(len(R_real)):    if (R_real[i] > Rkt):        print Rkt        print R        R.append(R_real[i])        Rkt = R_real[i]    print R
# Out:
# [300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 6000.0, 6000.0, 6000.0, 6000.0, 6000.0, 6000.0, 6000.0, 6000.0, 6000.0, 6000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 30000.0, 30000.0, 30000.0, 30000.0, 30000.0, 30000.0, 30000.0, 30000.0, 30000.0, 30000.0, 60000.0, 60000.0, 60000.0, 60000.0, 60000.0, 60000.0, 60000.0, 60000.0, 60000.0, 60000.0, 100000.0, 100000.0, 100000.0, 100000.0, 100000.0, 100000.0, 100000.0, 100000.0, 100000.0, 100000.0, 500000.0, 500000.0, 500000.0, 500000.0, 500000.0, 500000.0, 500000.0, 500000.0, 500000.0, 500000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0]0[0.29999999999999999]300.0[0.29999999999999999, 300.0]1000.0[0.29999999999999999, 300.0, 1000.0]3000.0[0.29
# ...
